# %% [markdown]
# <h1>Question Set A

# %%
#1) Rectangle Class
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * (self.length + self.width)

# Example usage:
rect = Rectangle(5, 3)
print("Area:", rect.area())
print("Perimeter:", rect.perimeter())
# Out:
# Area: 15
# Perimeter: 16

# %%
#2) BankAccount Class
class BankAccount:
    def __init__(self, balance=0):
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited: {amount}")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient balance!")
        else:
            self.balance -= amount
            print(f"Withdrawn: {amount}")

    def display_balance(self):
        print(f"Current balance: {self.balance}")

# Example usage:
account = BankAccount(1000)
account.deposit(500)
account.withdraw(300)
account.display_balance()
# Out:
# Deposited: 500
# Withdrawn: 300
# Current balance: 1200

# %%
#3) Vehicle, Car, and Bike Classes (Inheritance & Method Overriding)
class Vehicle:
    def __init__(self, brand):
        self.brand = brand

    def start(self):
        print(f"{self.brand} vehicle is starting.")

class Car(Vehicle):
    def start(self):
        print(f"{self.brand} car is starting with a key.")

class Bike(Vehicle):
    def start(self):
        print(f"{self.brand} bike is starting with a kick.")

# Example usage:
v = Vehicle("Generic")
v.start()

c = Car("Toyota")
c.start()

b = Bike("Honda")
b.start()
# Out:
# Generic vehicle is starting.
# Toyota car is starting with a key.
# Honda bike is starting with a kick.

# %%
#4) Student Class with Private Attributes
class Student:
    def __init__(self, name, age):
        self.__name = name      # private attribute
        self.__age = age        # private attribute

    # Public methods to access private attributes
    def get_name(self):
        return self.__name

    def set_name(self, name):
        self.__name = name

    def get_age(self):
        return self.__age

    def set_age(self, age):
        self.__age = age

# Example usage:
student = Student("Alice", 20)
print("Name:", student.get_name())
print("Age:", student.get_age())

student.set_name("Bob")
student.set_age(21)
print("Updated Name:", student.get_name())
print("Updated Age:", student.get_age())
# Out:
# Name: Alice
# Age: 20
# Updated Name: Bob
# Updated Age: 21

# %%
#5) Create a class Circle with method to calculate area. Overload the + operator to add two
#circles (add their radii).
import math

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

    # Operator overloading for +
    def __add__(self, other):
        if isinstance(other, Circle):
            return Circle(self.radius + other.radius)
        else:
            raise ValueError("Can only add another Circle")

    def __str__(self):
        return f"Circle with radius {self.radius}"

# Example usage:
c1 = Circle(3)
c2 = Circle(4)

print("Area of c1:", c1.area())
print("Area of c2:", c2.area())

# Adding two circles
c3 = c1 + c2
print(c3)
print("Area of c3 (sum of radii):", c3.area())
# Out:
# Area of c1: 28.274333882308138
# Area of c2: 50.26548245743669
# Circle with radius 7
# Area of c3 (sum of radii): 153.93804002589985

# %% [markdown]
# <h1>Question Set B

# %%
#1) Multilevel Inheritance: Animal -> Mammal -> Dog
class Animal:
    def eat(self):
        print("Animal is eating")

class Mammal(Animal):
    def walk(self):
        print("Mammal is walking")

class Dog(Mammal):
    def bark(self):
        print("Dog is barking")

# Example usage:
dog = Dog()
dog.eat()    # inherited from Animal
dog.walk()   # inherited from Mammal
dog.bark()   # Dog's own method
# Out:
# Animal is eating
# Mammal is walking
# Dog is barking

# %%
#2) Employee Class with Class Method to Count Employees
class Employee:
    total_employees = 0  # Class variable

    def __init__(self, name):
        self.name = name
        Employee.increment_count()

    @classmethod
    def increment_count(cls):
        cls.total_employees += 1

    @classmethod
    def get_total_employees(cls):
        return cls.total_employees

# Example usage:
e1 = Employee("Alice")
e2 = Employee("Bob")
e3 = Employee("Charlie")

print("Total employees:", Employee.get_total_employees())
# Out:
# Total employees: 3

# %%
#3) Book Class with __str__, __len__, __eq__
class Book:
    def __init__(self, title, pages):
        self.title = title
        self.pages = pages

    def __str__(self):
        return f"Book: {self.title}, Pages: {self.pages}"

    def __len__(self):
        return self.pages

    def __eq__(self, other):
        return self.pages == other.pages

# Example usage:
book1 = Book("Python Basics", 200)
book2 = Book("Advanced Python", 200)
book3 = Book("Java Basics", 150)

print(book1)          # __str__
print("Pages:", len(book1))   # __len__
print(book1 == book2) # __eq__ -> True
print(book1 == book3) # False
# Out:
# Book: Python Basics, Pages: 200
# Pages: 200
# True
# False

# %%
#4) Create a class Temperature with property decorators for Celsius and Fahrenheit
#conversion.
class Temperature:
    def __init__(self, celsius=0):
        self._celsius = celsius  # store temperature internally in Celsius

    # Celsius property
    @property
    def celsius(self):
        return self._celsius

    @celsius.setter
    def celsius(self, value):
        self._celsius = value

    # Fahrenheit property
    @property
    def fahrenheit(self):
        return (self._celsius * 9/5) + 32

    @fahrenheit.setter
    def fahrenheit(self, value):
        self._celsius = (value - 32) * 5/9


# --- Example usage ---
temp = Temperature(25)  # Initialize with 25°C
print("Celsius:", temp.celsius)          
print("Fahrenheit:", temp.fahrenheit)    

temp.fahrenheit = 212
print("Celsius after setting Fahrenheit to 212:", temp.celsius)  
print("Fahrenheit now:", temp.fahrenheit)
# Out:
# Celsius: 25
# Fahrenheit: 77.0
# Celsius after setting Fahrenheit to 212: 100.0
# Fahrenheit now: 212.0

# %% [markdown]
# <h1>Question Set C

# %%
#1) Abstract Class Shape with Subclasses
from abc import ABC, abstractmethod
import math

# Abstract base class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Rectangle subclass
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# Circle subclass
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

# Triangle subclass
class Triangle(Shape):
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def area(self):
        return 0.5 * self.base * self.height

# --- Example usage ---
shapes = [
    Rectangle(5, 10),
    Circle(7),
    Triangle(6, 8)
]

for shape in shapes:
    print(f"{shape.__class__.__name__} area:", round(shape.area(), 2))
# Out:
# Rectangle area: 50
# Circle area: 153.94
# Triangle area: 24.0

# %%
#2) Library Class to Manage Books
class Library:
    def __init__(self):
        self.books = []  # list to store book titles

    def add_book(self, book):
        self.books.append(book)
        print(f'"{book}" added to the library.')

    def remove_book(self, book):
        if book in self.books:
            self.books.remove(book)
            print(f'"{book}" removed from the library.')
        else:
            print(f'"{book}" not found in the library.')

    def search_book(self, book):
        if book in self.books:
            print(f'"{book}" is available in the library.')
        else:
            print(f'"{book}" is not found in the library.')

    def display_books(self):
        if self.books:
            print("Books in library:")
            for idx, book in enumerate(self.books, start=1):
                print(f"{idx}. {book}")
        else:
            print("Library is empty.")

# --- Example usage ---
lib = Library()
lib.add_book("Python Programming")
lib.add_book("Data Science 101")
lib.display_books()
lib.search_book("Python Programming")
lib.remove_book("Data Science 101")
lib.display_books()
# Out:
# "Python Programming" added to the library.
# "Data Science 101" added to the library.
# Books in library:
# 1. Python Programming
# 2. Data Science 101
# "Python Programming" is available in the library.
# "Data Science 101" removed from the library.
# Books in library:
# 1. Python Programming
